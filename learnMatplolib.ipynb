# %% [markdown]
# # Let's learn Matplotlib!
#  🎥 [screencast](https://youtu.be/aX2plNB8jLw)
#
#
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Mpl_screenshot_figures_and_code.png/752px-Mpl_screenshot_figures_and_code.png" width="50%">

# %% [markdown]
# ### What is Matplotlib
# [Matplotlib](https://matplotlib.org/) is the most popular library for creating static, animated, and "interactive" visualizations in Python (began in 2003).
#
# Produce static images (png default) and predates HTML5. Inspiration from Matlab.
#
# David McCandless, talking about the significance of data visualization in his [TED](https://www.youtube.com/watch?v=5Zg-C8AAIGg) talk said, “By visualizing information, we turn it into a landscape that you can explore with your eyes, a sort of information map. And when you’re lost in information, an information map is kind of useful.”
#
# ALternatives : [Plotly](https://plotly.com/python/), [Seaborn](https://seaborn.pydata.org/), [ggplot](http://ggplot.yhathq.com/), [Altair](https://altair-viz.github.io/), [Bokeh](https://bokeh.org/)...[difference](https://analyticsindiamag.com/top-5-python-libraries-for-data-visualization/)

# %% [markdown]
# #### Useful resources
#
# - 🎥 [screencast FR](https://youtu.be/aX2plNB8jLw)
# - [Corey Schafer EN](https://www.youtube.com/watch?v=UO98lJQ3QGI&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_&index=1) (Youtube tutorials)
# - [Matplotlib examples](https://matplotlib.org/3.1.1/gallery/index.html)

# %% [markdown]
# ### Traps to avoid
#
# - confusing vocabulary concepts, see FAQ (figure, axes, axis...) see [here](https://matplotlib.org/1.5.1/faq/usage_faq.html#parts-of-a-figure) and [here](https://matplotlib.org/faq/usage_faq.html#parts-of-a-figure)
# - 2 notations ("procedural" matlab-like or with variables/object oriented)
# - inches for figure size (1 inch = 2.54 cm)
# - hide unwanted text output: add ; or plt.show() [see here](https://stackoverflow.com/questions/12056115/disable-the-output-of-matplotlib-pyplot)
# - if plot is not visible add %matplotlib inline

# %% [markdown]
# ### Learning advices
#
# - copy/paste the data section and try to create a graph before checking the code!
# - learning advice : vocab intuition + integrated doc, search engine, [examples](https://matplotlib.org/), [tutorials](https://www.youtube.com/watch?v=UO98lJQ3QGI&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_)

# %%
#First let's import matplotlib and maybe pandas (for later)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Simple plots <a name="simplePlots"> </a>
# There's a plot function inside matplotlib, let's look at the inline doc appearing when using .plt.plot() - when opening the parenthesis or adding a coma. In Jupyter Notebook type Shift+Tab, then "+" for the doc to appear.
#
# The plot function needs at least y data
#
#
# ```
# plot([x], y, [fmt], *, data=None, **kwargs)
# ```

# %%
#@title
# plotting with y data
# random data
y=[3,8,23,44]

# %%
#@title
# code
plt.plot(y);

# %%
# plotting with x and y data
# data
y=[3,8,23,44]
x=[1,2,3,4]

# %%
#@title
# code
plt.plot(x,y)

# %% [markdown]
# Let's change the look, more infos at the bottom of the integrated doc

# %% [markdown]
# ```
# fmt = '[marker][line][color]'
# ```

# %% [markdown]
# #### formating symbols

# %% [markdown]
# - '.'          point marker
# - ','          pixel marker
# - 'o'          circle marker
# - 'v'          triangle_down marker
# - '^'          triangle_up marker
# - '<'          triangle_left marker
# -'>'          triangle_right marker
# - '1'          tri_down marker
# - '2'          tri_up marker
# - '3'          tri_left marker
# - '4'          tri_right marker
# - 's'          square marker
# - 'p'          pentagon marker
# - '*'          star marker
# - 'h'          hexagon1 marker
# - 'H'          hexagon2 marker
# - '+'          plus marker
# - 'x'          x marker
# - 'D'          diamond marker
# - 'd'          thin_diamond marker
# - '|'          vline marker

# %% [markdown]
# - 'b'	blue
# - 'g'	green
# - 'r'	red
# - 'c'	cyan
# - 'm'	magenta
# - 'y'	yellow
# - 'k'	black
# - 'w' white

# %% [markdown]
# - '-'	solid line style
# - '--'	dashed line style
# - '-.'	dash-dot line style
# - ':'	dotted line **style**

# %%
# green circles
plt.plot(x,y,'go')

# %%
# magenta square dotted line style
plt.plot(x,y,'ms:')

# %% [markdown]
# ### Saving plots <a name="savePlots"></a>
# Few possibilities.
# - in the browser (right clic on picture, save image in menu)
# - or with a command to export an image in the folder of your notebook (png, svg...)
# - you may need to do it in the same cell as the graph :
# ```
# plt.savefig('my_figure.png')
# plt.savefig('my_figure.svg',format="svg")

# %% [markdown]
# ### Multiple plots  <a name="multiplePlots"></a>
# Try to change the dot type and color for many plots?
# What happens to the color if we don't define it?

# %%
# data
x=[1,2,3,4]
y1=[3,8,23,44]
y2=[6,12,12,48]
y3=[10,20,33,54]

# %%
#@title
# code
plt.plot(x,y1,'p')
plt.plot(x,y2,'o')
plt.plot(x,y3,'D');

# %% [markdown]
# change yourself the color, marker and line style

# %%
#@title
plt.plot(x,y1,'rp-')
plt.plot(x,y2,'bo--')
plt.plot(x,y3,'mD:');

# %% [markdown]
# Add
#  labels, legends, grid, figure size,etc

# %%
#@title
plt.figure(figsize=(10,5))
plt.plot(x,y1,'p-',linewidth=2, markersize=12, label="apples")
plt.plot(x,y2,'o--',linewidth=4, markersize=1, label="oranges")
plt.plot(x,y3,'D:',linewidth=1, markersize=8,label="potatoes")
plt.grid(axis="x")
plt.title("The best graph")
plt.xlabel("year")
plt.ylabel("number")
plt.legend();

# %%
# Let's change the graph style
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Let's try fivethirtyeight, seaborn, ggplot, etc 
plt.style.use("fivethirtyeight") # "defalut" to go back to the default style
plt.figure(figsize=(10,5))
plt.plot(x,y1,'p-',linewidth=2, markersize=12, label="apples")
plt.plot(x,y2,'o--',linewidth=4, markersize=1, label="oranges")
plt.plot(x,y3,'D:',linewidth=1, markersize=8,label="potatoes")
plt.xlabel("Time")
plt.ylabel("Numbers")
plt.title("The trends")
plt.legend();

# %%
# Let's have graphs side by side
# data
x=[1,2,3,4]
y1=[3,8,23,44]
y2=[6,12,12,48]
y3=[10,20,33,54]

# %%
#@title
plt.style.use("fivethirtyeight")
plt.figure(figsize=(10,5))

plt.suptitle("Three graph")

plt.subplot(1,3,1) # nb rows, nb cols, index
plt.plot(x,y1,'p-',linewidth=2, markersize=12, label="apples")

plt.subplot(1,3,2)
plt.plot(x,y2,'o--',linewidth=4, markersize=1, label="oranges",color="orange")
plt.xlabel("Time")
plt.ylabel("Numbers")
plt.title("Orange")

plt.subplot(1,3,3)
plt.plot(x,y3,'D:',linewidth=1, markersize=8,label="potatoes", color="grey")
plt.xlabel("Time")
plt.ylabel("Numbers")
plt.title("Potatoes");

# %% [markdown]
# Same thing but with the object oriented way.

# %%
#@title
fig, ax = plt.subplots(1,3) # another way : fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(10,5))

fig.set_size_inches((10,5))

ax[0].plot(x,y1, 'p-')
ax[1].plot(x,y2, "o--", color="orange")
ax[2].plot(x,y3, 'D:', color="grey")

ax[0].set_xlabel("Time")
ax[0].set_ylabel("Number")
ax[0].set_title("apples")

ax[1].set_xlabel("Time")
ax[1].set_title("oranges")

ax[2].set_xlabel("Time")
ax[2].set_title("potatoes");

# %% [markdown]
# ### Pie charts <a name="pieCharts"></a>
#
# Works well with few data, let's take the population data by countries.

# %%
# data
countries=["Italy","France","UK","Germany"]
pop=[59.2,65.4,66.9,82.4]

# %%
#@title
plt.figure(figsize=(5,5))
plt.pie(pop, labels=countries,shadow=True);

# %%
#@title
plt.figure(figsize=(5,5))
plt.pie(pop, labels=countries,shadow=True,explode=[0,0.1,0,0],startangle=180);

# %%
#@title
plt.figure(figsize=(5,5))
wedgeprops={"edgecolor":"k",'linewidth': 2, 'linestyle': 'dashed', 'antialiased': True}
plt.pie(pop, labels=countries,shadow=True,explode=[0,0.1,0,0],startangle=180,
        wedgeprops=wedgeprops, autopct='%.2f%%');

# %% [markdown]
# ### Bar charts (simple, multi) <a name="barCharts"></a>

# %%
# create a bar graph with countries populations
# data
countries=["Italy","France","UK","Germany"]
pop=[59.2,65.4,66.9,82.4]

# %%
#@title
plt.bar(countries,pop)
plt.savefig("francePop.svg")

# %%
# the same kind of bar graph but horizontal
# data
countries=["Italy","France","UK","Germany"]
pop=[59.2,65.4,66.9,82.4]
color=["green","blue","red","yellow"]
variance=[1,2,3,4] # error margin, obvioulsy not true

# %%
#@title
plt.barh(countries, pop, color=color, edgecolor="black",xerr=variance)
plt.title("Populations")
plt.xlabel("Millions of people")
plt.ylabel("Countries")
plt.savefig("francePop.svg")

# %% [markdown]
# Same but oject oriented,

# %%
#@title
fig, ax=plt.subplots()
ax.barh(countries, pop, xerr=variance, color=color, edgecolor="black",)
ax.set_title("Populations")
ax.set_xlabel("Millions of people")
ax.set_ylabel("Countries")
# adavanced : writing values inside
for i, v in enumerate(pop):
  ax.text(pop[i]+5, i, pop[i])

# %%
# Two bar graphs comparison
# data
divisions=["Div1","Div2","Div3","Div4","Div5"]
girls=[16,11,18,7,14]
boys=[17,10,15,10,12]

# %%
#@title
index= np.arange(5)
barWidth=0.3
plt.bar(index,girls, width=0.3,label="Girls")
plt.bar(index+0.3,boys, width=0.3,label="Boys")
plt.title("Comparing 2 categories")
plt.xlabel("Divisions")
plt.ylabel("Boys vs average")
plt.xticks(index+barWidth/2,divisions)
plt.legend(loc="best");

# %%
#@title
index= np.arange(5)
barWidth=0.3
plt.bar(index,girls, width=0.3,label="Girls")
plt.bar(index,boys, width=0.3,label="Boys",bottom=girls)
plt.xticks(index,divisions)
plt.title("Comparing 2 categories")
plt.xlabel("Divisions")
plt.ylabel("Boys vs girls")
plt.legend(loc="best");

# %% [markdown]
# ### Stack plots <a name="stackPlots"></a>

# %%
# data from United Nations World Population Prospects (Revision 2019)
# data https://population.un.org/wpp/, license: CC BY 3.0 IGO
year = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2018]
continents=["africa","americas","asia","europe","oceania"]
popAfrica=[228, 284, 365, 477, 631, 814, 1044, 1275]
popAmericas=[340, 425, 519, 619, 727, 840, 943, 1006]
popAsia= [1394, 1686, 2120, 2625, 3202, 3714, 4169, 4560]
popEurope=[220, 253, 276, 295, 310, 303, 294, 293]
popOceania=[12, 15, 19, 22, 26, 31, 36, 39]

# %%
#@title
plt.figure(figsize=(10,5))
plt.stackplot(year,
              [popAfrica, popAmericas,popAsia,popEurope,popOceania],
              labels=continents);
plt.legend(loc="upper left");

# %%
# same from matplotlib examples but object notation and python dictionary usage
# data
year = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2018]
population_by_continent = {
    'africa': [228, 284, 365, 477, 631, 814, 1044, 1275],
    'americas': [340, 425, 519, 619, 727, 840, 943, 1006],
    'asia': [1394, 1686, 2120, 2625, 3202, 3714, 4169, 4560],
    'europe': [220, 253, 276, 295, 310, 303, 294, 293],
    'oceania': [12, 15, 19, 22, 26, 31, 36, 39],
}

#@title
fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys())
ax.legend(loc='upper left')
ax.set_title('World population')
ax.set_xlabel('Year')
ax.set_ylabel('Millions of people)')
fig.savefig("worldPop.svg")

# %% [markdown]
# Also see this [map density disbribution](http://www.statsmapsnpix.com/2020/11/how-to-make-3d-population-density.html) made with Blender.

# %% [markdown]
# ### Histograms <a name="histograms"></a>

# %%
# data
x= np.random.randint(0,1000,100) # start, end, nb of rands

# %%
#@title
plt.hist(x); # add paremeter bins for numbers of baskets : plt.hist(x,bins=20)

# %% [markdown]
# ### Time data <a name="timeData"></a>

# %%
# from a column in a dataframe
# data
df = pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/stock_data.csv",
                 parse_dates=True, index_col="Date")
df.head(3)
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA

# %%
# code
plt.plot(df["Open"])

# %% [markdown]
# See also Corey Schafer [tutorial](https://www.youtube.com/watch?v=_LWjaAiKaf8&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_&index=8) (Youtube) and this Medium [article](https://towardsdatascience.com/an-ultimate-guide-to-time-series-analysis-in-pandas-76a0433621f3)

# %% [markdown]
# ### Animated data <a name="animatedData"></a>
#
# See Corey Schafer [tutorial](https://www.youtube.com/watch?v=Ercd-Ip5PfQ&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_&index=9) (Youtube)

# %% [markdown]
# ### 3D Plots <a name="3Dplots"></a>

# %%
# data
pos=np.random.rand(3,100) # 3 series of 100 random numbers between 0 and 1





# code
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter3D(xs=pos[0],ys=pos[1],zs=pos[2])

# %%
# you can sets limits, multiply a numpy array...
# data
pos=np.random.rand(3,100)
# code
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_zlim(0,10)
ax.scatter3D(xs=pos[0]*10,ys=pos[1]*10,zs=pos[2]*10)

# %%
# plotting an equqtion in 3D 
# data
z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)





# code
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
plt.xticks(np.arange(-1, 1, step=0.5)) # optional : improving axis reading
ax.plot3D(x_line, y_line, z_line, 'green')

# %% [markdown]
# See also this [article](https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html) for more 3D plotting options.

# %% [markdown]
# ### Data random & ranges (numpy) <a name="randomData"></a>
#
# See in this [notebook](https://colab.research.google.com/drive/1dH418bXTCAGx4iUZ1Xkw4NCpDT6rJSWI)

# %% [markdown]
# ### from dataframe or Python dictionary <a name="dataFrame"></a>

# %%
# plot from a dictionary ("procedural" way)
d = {'col1': [1, 2], 'col2': [3, 4]}
plt.plot("col1","col2",data=d)

# %%
# or plot form a dataframe               
df = pd.DataFrame(data=d)
plt.plot("col1","col2",data=d)

# %%
# or directly a column from a dataframe (Facebook stock)
df = pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/stock_data.csv",parse_dates=True, index_col="Date")
plt.plot(df["Open"])
